# %% [markdown]
# # 1.  Explore Orders
#
# ### Task
#
# Answer the following questions using Pandas.
#
# 1. How many orders are in the dataset?
# 2. What are the available order statuses?
# 3. How many orders exist for each status?
# 4. Which status has the most orders?
#
# Use the cells below.

# %%
# Question 1: How many orders are in the dataset?

# Your code here

# %%
# Question 2: What are the available order statuses?

# Your code here

# %%
# Question 3: How many orders exist for each status?

# Your code here

# %%
# Question 4: Which status has the most orders?

# Your code here

# %% [markdown]
# # 2.Filtering
#
# Task
# Create a DataFrame containing only delivered orders and determine how many there are.

# %%
# Create a DataFrame containing only delivered orders

# Your code here

# %%
# Count the delivered orders

# Your code here

# %% [markdown]
# # 3.  Seller Analysis
#
# Using the `order_items` table:
#
# 1. Calculate total sales per seller.
# 2. Calculate average item price per seller.
# 3. Count the number of items per seller.
# 4. Sort sellers by total sales.
# 5. Display the top 10 sellers.

# %%
# Your code here

# %% [markdown]
# # 4.  Individual Practical Assessment
#
# ## Task
#
# Choose either the `orders` or `order_items` table and conduct a short exploratory analysis.
#
# ### Minimum requirements
#
# Your notebook must include:
#
# -  Dataset inspection
# -  At least one column selection
# -  At least one filtering operation
# -  At least one sorting operation
# -  At least one `groupby()` operation
# -  At least one aggregation
# -  At least 3 meaningful findings
# -  A short conclusion
#
# ### Questions
#
# #### Orders
# - What is the most common order status?
# - How many orders are delivered?
# - How many orders are cancelled?
# - Are there missing values in important fields?
#
# #### Order Items
# - What is the average product price?
# - Which sellers have the highest total sales?
# - Which items are the most expensive?
# - Which sellers have the highest number of items?
#
# ### Note
#
# Do not only display code. Explain what your results mean.

# %%
# ============================
# YOUR MINI PROJECT STARTS HERE
# ============================

# 1. Inspect your selected table


# 2. Select useful columns


# 3. Filter records


# 4. Sort records


# 5. Group and aggregate


# 6. Record your findings

# %% [markdown]
# # 5. Findings
#
# Write at least three findings from your analysis.
#
# ### Finding 1
# *Write your finding here.*
#
# ### Finding 2
# *Write your finding here.*
#
# ### Finding 3
# *Write your finding here.*

# %% [markdown]
# # 6. Conclusion
#
# Summarise what your analysis tells us about the Olist marketplace.
#
# Consider:
#
# - What did you discover?
# - Which result was most interesting?
# - What business decision could potentially be informed by your analysis?

# %% [markdown]
# # 7. Assessment Rubric
#
# | Criteria | Marks |
# |---|---:|
# | Dataset successfully loaded | 5 |
# | Dataset exploration | 15 |
# | Column selection | 5|
# | Filtering | 10 |
# | Sorting | 5 |
# | `groupby()` | 15 |
# | Aggregation | 15 |
# | Interpretation of results | 25 |
# | Notebook organization / clean code | 5 |
# | **Total** | **100** |
#
# ** pass mark: 80%**
